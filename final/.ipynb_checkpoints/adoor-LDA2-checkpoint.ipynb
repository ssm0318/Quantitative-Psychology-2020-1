# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import os
import csv
import textract
import nltk
import joblib

import MeCab
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from konlpy.tag import *
from collections import Counter
from nltk.corpus import stopwords
import pyLDAvis.sklearn
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %matplotlib inline

# %%
df = pd.read_csv('adoor_data/answers.csv', encoding='UTF8')
df['created_at'] = pd.to_datetime(df['created_at'])

start_date = pd.Timestamp(2019, 1, 28, 0)
end_date = pd.Timestamp(2019, 4, 1, 0)

mask = (df['created_at'] > start_date) & (df['created_at'] <= end_date)
df = df.loc[mask]

df.head()
# Out:
#    id  author_id  question_id  \
# 0   1          5          236
# 1   2          5          103
# 2   3          5           98
# 3   4          5           95
# 4   6          4            5
#
#                                              content  tag_string  \
# 0  오늘 상담쌤과 칭찬에 대한 대화를 나눴다. 내가 애들의 칭찬을 잘 못 믿는, 그리고...         NaN
# 1         원하는 순간에 생각의 흐름을 멈추고 하고자 하는 일에 집중할 수 있는 능력.         NaN
# 2                              가만히 공상/유튜브. 혼자 있는 시간.         NaN
# 3  게으름. 그 중에서도 요즘 가장 싫은건 게으름으로 인해 더러워진 방. 너무 짜증나서...         NaN
# 4                     진수니랑 같이 프론트 더 멋있게 만들기!!!!!\r\n         NaN
#
#                   created_at                  updated_at
# 0 2019-01-28 14:11:42.543635  2019-01-28 14:11:42.543635
# 1 2019-01-28 14:12:09.623446  2019-01-28 14:12:09.623446
# 2 2019-01-28 14:13:16.547800  2019-01-28 14:13:16.547800
# 3 2019-01-28 14:14:38.838070  2019-01-28 14:14:38.838070
# 4 2019-01-28 15:55:14.088330  2019-01-28 15:55:14.088330

# %%
def getNVM_lemma(text):
    tokenizer = MeCab.Tagger()
    parsed = tokenizer.parse(text)
    word_tag = [w for w in parsed.split("\n")]
    pos = []
    tags = ['NNG','NNP','VV','VA', 'VX', 'VCP','VCN']
    for word_ in word_tag[:-2]:
        word = word_.split("\t")
        tag = word[1].split(",")
        if(len(word[0]) < 2) or ("게" in word[0]):
            continue
        if(tag[-1] != '*'):
            t = tag[-1].split('/')
            if(len(t[0]) > 1 and ('VV' in t[1] or 'VA' in t[1] or 'VX' in t[1])):
                pos.append(t[0])
        else:
            if(tag[0] in tags):
                pos.append(word[0])
    return pos

# %%
tf_vect = CountVectorizer(tokenizer=getNVM_lemma, min_df=2, max_df=6000, max_features=25000)
dtm = tf_vect.fit_transform(df['content'].values.astype('U'))

n_topics = 5

lda = LatentDirichletAllocation(n_components=n_topics, topic_word_prior=0.01, doc_topic_prior=0.001)
lda.fit(dtm)
saved_model = joblib.dump(dtm, 'LDA_IP.pkl')

# %%
names = tf_vect.get_feature_names()
topics_word = dict()
n_words = 10

for idx, topic in enumerate(lda.components_):
    vocab = []
    for i in topic.argsort()[:-(n_words-1):-1]:
        vocab.append((names[i], topic[i].round(2)))
    topics_word[idx+1] = [(names[i], topic[i].round(2)) for i in topic.argsort()[:-(n_words-1):-1]]
max_dict = dict()
for idx, vec in enumerate(lda.transform(dtm)):
    t = vec.argmax()
    if(t not in max_dict):
        max_dict[t] = (vec[t], idx)
    else:
        if(max_dict[t][0] < vec[t]):
            max_dict[t] = (vec[t], idx)
            
sorted_review = sorted(max_dict.items(), key = lambda x: x[0], reverse=False)

for key, value in sorted_review:
    print('주제 {}: {}'.format(key+1, topics_word[key+1]))
    print('[주제 {}의 대표 글 :{}]\n{}\n\n'.format(key+1, value[0], df['content'].values.astype('U')[value[1]]))
# Out:
# 주제 1: [('행복', 37.64), ('생각', 29.25), ('사람', 21.1), ('친구', 21.05), ('질문', 19.83), ('모르', 18.99), ('시간', 18.08), ('대하', 17.57)]
# [주제 1의 대표 리뷰 :0.9999436659390181]
# 이 질문을 보고 내가 진짜 싫어하는 소확행, 힐링을 강요하는 사회 뭐 이런 게 생각나서 궤변을 한 번 지어내 봤당 물론 질문 자체에는 전혀 문제가 없지만!! 내가 이 질문에서 불편함을 느끼게 하는 (그래서 멀쩡한 질문에 답은 안 하고 이상한 소리만 하게 만드는) 숨겨진 맥락은 분명히 존재한다. 사실은 내가 평소에 평화라는 거에 대해 생각을 안 하고 사는 아무 생각이
# 없는 사람이라 대답할 말이 생각 안 나서 이런 걸 쓰는 걸 수도 있당...ㅎ.ㅎ.ㅎ.ㅎ.ㅎ 사실 얼마 전에 비슷한 논지의 글을 봐서 그거의 내용은 다 가져다 쓰면서 논리는 1도 없는 글인 걸 알아서 부끄럽지만 여기는 어도어니까~
#
# 이 사악한 질문은 두 가지를 숨기고 있다.
# 1. 평화라는 말은 애초에 한 개인에게 적용할 수 없는 단어임에도 불구하고, 주어를 1인칭으로 설정하고 구어체를 사용함으로써 평화라는 말을 개인이 처한 상황과 관련지어 생각하도록 유도한다.
# 2. 따라서 이 질문을 받은 개인은 여기서 평화라는 말을 평온 또는 행복과 비슷한 의미를 가진 것으로 왜곡해서 생각하게 되고, 세 단어가 실제로는 모두 다른 의미의 단어임에도 불구하고 그것들의 의미를 서로 혼동해 '조용하고 만족스러운' 정도의 평화도 평온도 행복도 아닌 어중간하고 부족한(?) 것을 답하고 그것을 평화고 평온이며 행복이라고 받아들인다. 하지만 그 답변은 셋 중 무엇도 아니다.
# 이런 암시적이고 편향적인 질문에 넘어가서 이 질문이 의도하는 종류의 대답을 해 버리고 싶지는 않다. 힐링은 아프기 때문에 할 수 있는 것이고, 대부분의 소확행은 강요되는 것이다.
#
#
# 주제 2: [('사람', 53.91), ('생각', 38.29), ('그러', 19.85), ('자신', 16.61), ('시간', 16.01), ('마음', 15.49), ('이야기', 13.92), ('그렇', 12.77)]
# [주제 2의 대표 리뷰 :0.9999403029624652]
# 키키 내가 좋아하는 꿈 이야기당 (내가 꾼 꿈)
# 어제어제!! 손흥민이 나왔다 아마 그저께 우리나라 축구 친선경기를 5분 정도 봐서 그런가 보다 손흥민이랑 황..황..의조!도 나온 걸 보니~
#  나랑 내 친구가 다이소에 갔는데 손흥민이 장바구니를 들고 쇼핑을 하고 있었다 우리는 깜짝 놀랐고 쇼핑을 하러 갔다 그 다이소는 2층짜리였고 우리가 2층에서 1층으로 내려가는데 그때도 손흥민이 있었고 1층에 먼저 내려가 있던 친구와 내려가는 계단에 있던 내가 눈마주치며 엄청 놀라며 좋아했다 (들어올 때 봤을 때보다 더) 그리고 손흥민은 계산을 다 했는지 큰 짐을 들고나갔다
# 이제 중요한 건 그 뒤의 이야기!
# 손흥민 축구 관계자분이 손흥민이랑 통화를 한다는데 내가 그 옆에 있었고 그 분이 갑자기 폰을 내게 건넸다 그리고 손흥민은 내가 그분인줄 알고 "~몇 년인데"이러는데 내가 "아.. 안녕하세요..." 라고 했고 손흥민이 "아 누구세요....?"래서 내 소개를 했다 갑자기 전화를 받게 되었다고 하면서ㅋㅋㅋㅋㅋ그러면서 손흥민과 통화를 했다!!!! 통화하다 관계자분이 얼른 끊으라고 손흥민 피곤할 거라고 해서 내가 "혹시 지금 피곤하세요? 지 금 누워계세요?"라고 당돌한 건지 무례한 건지 그렇게 물어봤고 손흥민은 안 피곤하다고 해서 내가 관계자분께 "안 피곤하대요!!"라고 했다 그리고 손흥민에게 "아 제가 진짜 궁금한 거 하나만 여쭤보고 싶은데,, 그 손흥민님(호칭을 뭐라고 했는지 기억이 안 난다)을 지나가다가 호오오옥시나 보게 되었을 때 그니까.. 손흥민님은 정말 가끔 오는 휴가 일텐데... 그래도 그럴 때 호오오오옥시 사진 찍어달라고 해도 되나요.....?"라고 아주아주 조심스럽지만 마음을 표현하며 질문을 했다 그리고, "...."라는 반응이 와서 "아 죄송해요ㅠㅠ"라니까 "ㅎㅎ아시잖아요" 라고 아주 단호박스러운 대답이 돌아왔다~~~~~! 그렇지만 나는! "아ㅎㅎ그래도.. 인생 마지막 경험일 수 있어서..."라며 현실 나처럼 아주 말대답을 했다 그리고 손흥민은 전화를 끊어버렸다 정말 당황스러웠다
# 전화 끊기고 관계자분께 "저 진짜 오래 통화했죠! 얼마나 했어요?" , "16분" 16분 했다!!! 그러고 그분이 손흥민한테 전화를 걸었는데 손흥민이 "인생 마지막 경험이라는데 끊어줘야지"라 했나 그런 말을 했고.. 그랬다.. 그렇게 나는 토요일 아침을 맞이했다
#
#
# 주제 3: [('사람', 47.79), ('생각', 34.84), ('괜찮', 33.95), ('경우', 27.89), ('고민', 17.96), ('문제', 16.01), ('선택', 16.0), ('최악', 15.61)]
# [주제 3의 대표 리뷰 :0.999974684345432]
# 생각해보니 상당히 많은 사람들이 괜찮은 척을 하고 산다. 분야는 조금씩 다르기는 하지만.
# 그런데 이런 시나리오들에서 누구나 괜찮지 않은 모멘트가 발생한다는 가정 하에
# 괜찮지 않음 --> 괜찮은 척을 함/하지 않음 --> 괜찮아 짐/지지 않음 에서
# 일단 가장 중요한 것은 빠르게 괜찮아지는 것이라고 생각한다. 스스로든 외부의 힘을 빌려서든 빠르게 괜찮아지는거, 그게 사람들이 말하는 회복탄력성이자 자기주도성, 적절한 소통의 결과물인 것 같다.
# 그 다음 중요한 것이 괜찮은 척인데, 1. 괜찮지 않은 모멘트가 자주 발생하지 않음 2. 빠르게 괜찮아짐 의 두 조건을 만족하는 사람의 경우 괜찮은 척을 하지 않아도 크게 상관이 없는 것 같다. 그런데 1을 만족시키지 못하는 사람의 경우 주위 사람들을 피곤하게 할 수 있어서 많은 주의가 필요한 것 같다. 2만 만족시키지 못하는 경우는 1만 만족시키지 못하는 경우보다는 나은 것 같은데, 그래도 괜찮지 않은 상태 그 자체가 발생시키는 영향들이 prolong된다는 점에서 경우에 따라 좀 위험한 것 같다. 1,2를 둘 다 만족시키지 못하면서 괜찮은 척도 하지 않은다...?이런 경우는 그냥 주위에 사람이 없어서 도태되지 않을까 싶다. 예외는 슬프게도 겁나 많다. 주변 사람들이 보살이던가 아니면 그 사람이 어떤 종류던지간에 권력을 가지고 있어 없애지를 못하던가 (e.g. 수많은 성격파탄 국회의원/CEO/교수들).
# 괜찮아짐이 회복탄력성/자기주도성/소통의 결과라면 괜찮은 척은 사회성에서 비롯되는 것 같은데 (비록 여성들의 사회에서는 사회성에 대한 많이 왜곡된 기준이 적용되는 것 같기는 하지만) 사회성의 힘을 맹신하면 안 되는 것 같다. 일단 더 중요한 것은 빠르게 괜찮아지는 것이라는 점을 기억해야할 것 같다. 스스로 기분/생각을 전환하거나, 적극적으로 자신의 괜찮지 않음을 소통해서 괜찮지 않은 문제를 해결하거나, 괜찮지 않음의 원인이 본질적이라 개선되지 않을 것 같은 경우 그것을 빠르게 인지하고 문제로부터 멀어지거나. 괜찮지 않은 채로 문제를 덮고 subpar 상태로 있는 것은 언제든 정말 좋지 못하다.
# 그렇다면 나는 어떤가. 나는 평소에는 괜찮지 않은 빈도나 괜찮아지는 속도는 평균적인 것 같고 괜찮은 척은 잘 못한다. 그런데 문제가 좀 더 본질적인 것에 가깝거나 큰 문제일 경우, 혹은 나만 바라보고 있는 문제일 경우 괜찮은 척을 하기는 하지만 passive aggressive하게 대응을 하는 경우가 많다. 문제의 본질을 놓치는 경우도 많다. 그리고 괜찮아지는 속도도 많이 더뎌진다. 건강한 사고와 소통을 제대로 못한다는 거다. 오늘 본 vulnerability에 대한 글에서도 일맥상통하는 측면에서 찔리는 부분이 매우 많았다.
# 그러면 앞으로 어떻게 해야 할까. 솔직히 나도 잘 모르겠다. 일단은 본질적인 한계와 현실적인 한계를 구분하는 과정에 있다. 큰 그림을 더 잘 볼 수 있는 상태가 되어야할 것 같고 많은 사람들과 대화해봐야할 것 같다. 아직 많은 부분에서 성장이 필요하다.
#
#
# 주제 4: [('사람', 96.37), ('생각', 37.32), ('겨울', 31.97), ('아니', 29.74), ('노래', 18.01), ('여름', 16.58), ('마음', 15.25), ('사랑', 15.01)]
# [주제 4의 대표 리뷰 :0.9999310404275494]
# 아마도 많은 사람들이 모르는 나의 나다움
# 나는 자주 사람들에 대해 생각한다
# 지나간 일을 생각하다 어떤 사람의 어떤 순간이 생각난다
# 그 때의 표정을 생각하고 그 때 했던 말과 말투를 생각하고 그 때 했던 행동에 담긴 그 사람의 마음과 그 때 느꼈을 감정을 생각하다
# 아무도 그 사람의 그 순간을 알아주지 않았다는 생각이 들면 그 사람을 내가 알아주고 싶고 그 사람의 그 순간을 내가 왜 놓쳤을까 생각한다
# 그 사람의 마음이 예뻐보이고 아파보이고 외로워보여 그 사람이 좋아진다
# 고마움과 아끼는 마음을 꼭 알려줘야지 생각하고 편지를 쓰려하면 다 둥둥 떠다니는 말들처럼 느껴진다 형체가 없는 걸 표현하는 건 어렵다 어떻게 표현해도 내가 알려주고 싶은 그 지점이 적절한 온도로 전해지지 않는다 나는 겁쟁이라서 직접 말해주는 건 더 못한다 그래서 진부한 말을 한다
# 오늘 죽는다면 편지를 500장 쓸거라고 했지만 아마도 쓰다 포기할 거다 내 무덤을 파면 내가 살아생전 토해내지 못한 감정조각들만 남아있을지도 모른다
#
#
# 주제 5: [('생각', 41.35), ('사람', 29.88), ('칭찬', 25.01), ('사랑', 20.01), ('실망', 17.01), ('바꾸', 15.01), ('정도', 13.01), ('여름', 11.44)]
# [주제 5의 대표 리뷰 :0.9999354890734619]
# '주눅, 뻘쭘, 짜증'
# 알바 초반에는 일에 능숙하지 못하다 (이건 자연스럽다고 볼 수 있따, 그리고 일이 좀 익숙해지면 속도가 화-악 빨라진당) 그래서 실수도 하고 뭘 하든 좀 느리고 그른다. 그럴 때 일하는 분이 답답해하는 게 느껴지거나 내가 도움이 안된다는 게 느껴질 때 '주눅'든다 그게 싫타,,  리미니때부터 그냥 알바 초반엔 거의 그런 감정으로 시작해왔고,,
# 그리고 알바 3일째인 오늘도 그랬다 그니까 좀 그런 것 같다 나는 내 속도가 있는 건데 나도 하려고 했고 할 수 있는데 다른 분들이 생각하는 속도는 나보다 빠르니까, 다르니까 .. 큐큐큐큐 징짜 솔직히 막상 일할 때는 '~해달라, ~해라, ~해야지, ~왜 안 했니' 라고 하시면서 또 '괜찮으니까 천천히 해라, 기다릴 수 있다, 성급해하지 않아도 된다' 라고 하신다.. 아 고럼 10초 정도만 조금 있어주시면... 후아 사람들이 그렇게나 못 기다려주나? 아 급한 사람들도 있기야 하겠지만 진짜.. 그래.. 이건 인간성의 문제가 아닌 거겠지..
# 그리고 증말 사람들이 음료를 너무 많이 마시는 것 같다 음료 마시는 걸 줄이는 운동을 했으면 좋겠다^^^^^^^^^ 그치만 음료가 필요하겠지,, 그냥 밥에 음료가 포함되는 거겠지 이젠,,,,
# 알바 얘기로 참 할 말이 많다^----------^
# 웃긴 게 진짜 알바 새로 시작할 때마다 그 전 알바가 그리워진다 아니다 매번은 아니고 그냥 학원 알바가 이디야가 그립다,, 이디야도 조금 점장님께서 다그치는 게 있긴 하셨지만,,, 그래도 재미는 있었다,,,,,,, 난 진짜 재미가 중요한 것 같다,,,,,,,,, 특히나 일하는 거에 있어서,,,,,,,,,,,,,
# 진짜 알바는 정말정말정말정말정말 참 생각이 많이 들 게 만드는 일이다 ^^^^^^^^
# 또 하나 내 생각 주머니가 추가되었다 아니 다시 돌아왔다~~~~~~~ 귣~~~~!~!

# %%
visual = pyLDAvis.sklearn.prepare(lda_model=lda, dtm=dtm, vectorizer=tf_vect)
pyLDAvis.save_html(visual, 'LDA_Visualization2.html')
pyLDAvis.display(visual)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el