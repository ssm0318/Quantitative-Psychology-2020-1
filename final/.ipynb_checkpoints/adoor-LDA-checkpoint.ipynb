# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import os
import csv
import textract
import nltk

import MeCab
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from konlpy.tag import *
from collections import Counter
from nltk.corpus import stopwords
import pyLDAvis.sklearn
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %matplotlib inline

# %%
df = pd.read_csv('adoor_data/answers.csv', encoding='UTF8')
df['created_at'] = pd.to_datetime(df['created_at'])

# df = df[df['author_id'] != 5]

start_date = pd.Timestamp(2019, 1, 28, 0)
end_date = pd.Timestamp(2019, 4, 1, 0)

mask = (df['created_at'] > start_date) & (df['created_at'] <= end_date)
df = df.loc[mask]

df.head()
# Out:
#    id  author_id  question_id  \
# 0   1          5          236
# 1   2          5          103
# 2   3          5           98
# 3   4          5           95
# 4   6          4            5
#
#                                              content  tag_string  \
# 0  오늘 상담쌤과 칭찬에 대한 대화를 나눴다. 내가 애들의 칭찬을 잘 못 믿는, 그리고...         NaN
# 1         원하는 순간에 생각의 흐름을 멈추고 하고자 하는 일에 집중할 수 있는 능력.         NaN
# 2                              가만히 공상/유튜브. 혼자 있는 시간.         NaN
# 3  게으름. 그 중에서도 요즘 가장 싫은건 게으름으로 인해 더러워진 방. 너무 짜증나서...         NaN
# 4                     진수니랑 같이 프론트 더 멋있게 만들기!!!!!\r\n         NaN
#
#                   created_at                  updated_at
# 0 2019-01-28 14:11:42.543635  2019-01-28 14:11:42.543635
# 1 2019-01-28 14:12:09.623446  2019-01-28 14:12:09.623446
# 2 2019-01-28 14:13:16.547800  2019-01-28 14:13:16.547800
# 3 2019-01-28 14:14:38.838070  2019-01-28 14:14:38.838070
# 4 2019-01-28 15:55:14.088330  2019-01-28 15:55:14.088330

# %%
def getNVM_lemma(text):
    tokenizer = MeCab.Tagger()
    parsed = tokenizer.parse(text)
    word_tag = [w for w in parsed.split("\n")]
    pos = []
    tags = ['NNG','NNP','VV','VA', 'VX', 'VCP','VCN']
    for word_ in word_tag[:-2]:
        word = word_.split("\t")
        tag = word[1].split(",")
        if(len(word[0]) < 2) or ("게" in word[0]):
            continue
        if(tag[-1] != '*'):
            t = tag[-1].split('/')
            if(len(t[0]) > 1 and ('VV' in t[1] or 'VA' in t[1] or 'VX' in t[1])):
                pos.append(t[0])
        else:
            if(tag[0] in tags):
                pos.append(word[0])
    return pos

# %%
tf_vect = TfidfVectorizer(tokenizer=getNVM_lemma,ngram_range=(1, 2), min_df=2, max_df=20000) 
dtm = tf_vect.fit_transform(df['content'].values.astype('U'))

n_topics = 3

lda = LatentDirichletAllocation(n_components=n_topics) 
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=3)

# %%
names = tf_vect.get_feature_names() 
topics = dict() 

for idx, topic in enumerate(lda.components_): 
    vocab = [] 
    for i in topic.argsort()[:-(10-1):-1]: 
        vocab.append((names[i], topic[i].round(2))) 
    print("주제 %d:" % (idx +1)) 
    print([(names[i], topic[i].round(2)) for i in topic.argsort()[:-(10-1):-1]])
# Out:
# 주제 1:
# [('사람', 28.34), ('친구', 11.95), ('힘들', 7.45), ('마음', 7.01), ('배우', 7.0), ('질문', 6.75), ('인생', 6.56), ('그러', 5.8)]
# 주제 2:
# [('생각', 20.66), ('모르', 12.9), ('시간', 9.29), ('자신', 8.01), ('겨울', 7.14), ('오늘', 7.05), ('보이', 6.71), ('여름', 6.34)]
# 주제 3:
# [('사랑', 11.57), ('편지', 6.87), ('생각', 6.85), ('어렵', 6.85), ('행복', 6.74), ('사람', 6.34), ('실망', 6.1), ('최악', 5.75)]

# %%
visual = pyLDAvis.sklearn.prepare(lda_model=lda, dtm=dtm, vectorizer=tf_vect) 
pyLDAvis.save_html(visual, 'LDA_Visualization.html') 
pyLDAvis.display(visual)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el71701405785302316326268923577"></div>
# <script type="text/javascript">
#
# var ldavis_el71701405785302316326268923577_data = {"mdsDat": {"x": [0.0715083330776489, -0.09760673536916817, 0.026098402291519288], "y": [-0.06535320972503832, -0.023989987694815838, 0.08934319741985418], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [37.94575412304204, 33.04126021863185, 29.012985658326112]}, "tinfo": {"Term": ["\uc0ac\ub791", "\ubaa8\ub974", "\uc0dd\uac01", "\uce5c\uad6c", "\uc0ac\ub78c", "\ud3b8\uc9c0", "\uaca8\uc6b8", "\uc790\uc2e0", "\uc2e4\ub9dd", "\uc624\ub298", "\ucd5c\uc545", "\uc5ec\ub984", "\uc2dc\uac04", "\ud798\ub4e4", "\ubc30\uc6b0", "\ud589\ubcf5", "\uae30\uc5b5", "\uc5b4\ub835", "\ubcf4\uc774", "\uc758\uc9c0", "\uc9c8\ubb38", "\uacbd\uc6b0", "\uc77c\uc5b4\ub098", "\uc218\uc5c5", "\ud544\uc694", "\uc5c4\ub9c8", "\uc120\ud0dd", "\ubc14\uafb8", "\ub9cc\ub098", "\ubb34\uc12d", "\ubc30\uc6b0", "\ud798\ub4e4", "\ub9cc\ub098", "\uc9c8\ubb38", "\uc601\ud654", "\ud558\ub8e8", "\uace0\ubbfc", "\ud559\uad50", "\uce5c\uad6c", "\uc0dd\uae30", "\uac74\uac15", "\ub9db\uc788", "\uc2dc\uc791", "\uc598\uae30", "\ubaa9\ud45c", "\uc0ac\uc2e4", "\uc54c\ub9ac", "\uac1c\uac15", "\uc21c\uac04", "\uc9c0\uae08", "\ud3c9\uc0dd", "\ub300\ud654", "\uc9c1\uac10", "\uace0\ud1b5", "\ubc14\ub00c", "\uc0dd\uac01\ub098", "\ubc15\uc9c0\ubbfc", "\uc815\ub9ac", "\ubbf8\uce58", "\ubd88\ud589", "\uc778\uc0dd", "\uc0ac\ub78c", "\uc774\uc57c\uae30", "\ub9c8\uc74c", "\uae30\ubd84", "\uadf8\ub7ec", "\uc544\ub2c8", "\ud589\ubcf5", "\uce6d\ucc2c", "\uc2dc\uac04", "\uc0dd\uac01", "\uaca8\uc6b8", "\uc624\ub298", "\uc5ec\ub984", "\ubaa8\ub974", "\ubc14\uafb8", "\uc5c4\ub9c8", "\uc790\uc2e0", "\uc5ec\ud589", "\ubb34\uc12d", "\ub098\uac00", "\ub9c8\uc2dc", "\uce68\ub300", "\uc544\uc774", "\uac10\uc0ac", "\ub4b9\uad74", "\ud53c\ud558", "\uc5f0\ub77d", "\uc18c\ub9ac", "\ubb38\uc81c", "\ubcf4\uc774", "\ucd08\ucf54", "\uc218\uc815", "\uc7a0\ub4e4", "\uac00\ub9ac", "\uba4b\uc9c0", "\uc790\ub791", "\uc678\ub86d", "\ubc1c\ub9ac", "\uc624\ub974", "\uc2a4\ud0c0", "\uc5bc\uad74", "\uc778\uac04", "\uc0dd\uac01", "\uad1c\ucc2e", "\uc2dc\uac04", "\uacf5\ubd80", "\ubc84\ub9ac", "\ub3cc\uc544\uc624", "\uc874\uc7ac", "\uc544\ub2c8", "\uc0ac\ub78c", "\uc0ac\ub791", "\uc2e4\ub9dd", "\ucd5c\uc545", "\ud3b8\uc9c0", "\uc758\uc9c0", "\uc77c\uc5b4\ub098", "\uc218\uc5c5", "\uc120\ud0dd", "\uacbd\uc6b0", "\ub5a0\uc62c\ub9ac", "\uc7ac\ubc0c", "\uc5ec\uc720", "\uce5c\ud558", "\ucd5c\uc120", "\ud734\ud559", "\uac15\ud558", "\uae30\uc5b5", "\ucd5c\uc545 \uacbd\uc6b0", "\ubb34\uac81", "\uc219\uc81c", "\ud544\uc694", "\uc5b4\ub9ac", "\uc695\ub9dd", "\uc54c\ub78c", "\uc544\ub984\ub2f5", "\uc6b0\uc8fc", "\ucc98\uc74c", "\uc0ac\ub791 \uc0ac\ub78c", "\ub9db\ub098", "\uc885\uac15", "\uc5b4\ub835", "\uadf8\ub807", "\uc774\uc720", "\ubaa8\uc2b5", "\uc815\ub3c4", "\ud589\ubcf5", "\uc9c0\ub098", "\uae30\ub300", "\ub3c4\uc5b4", "\ub290\ub07c", "\uc0dd\uac01", "\ub3d9\uc548", "\uc0ac\ub78c", "\uac10\uc815", "\ub9cc\ub4e4", "\uc138\uc0c1", "\ub300\ud558"], "Freq": [7.0, 8.0, 19.0, 8.0, 24.0, 4.0, 4.0, 5.0, 4.0, 4.0, 3.0, 4.0, 8.0, 5.0, 4.0, 7.0, 4.0, 6.0, 4.0, 3.0, 4.0, 3.0, 3.0, 3.0, 3.0, 3.0, 2.0, 3.0, 3.0, 3.0, 4.339609962913536, 4.618602153520215, 3.5751644090598518, 4.18338982894229, 3.4268613124418765, 3.5762536356925705, 3.408029842489753, 3.4398165326773946, 7.414403365159549, 2.8931405485215684, 2.7438898827792455, 2.6344366598868034, 2.676915686903034, 2.4596682155409533, 2.459248272326845, 2.317309295831493, 2.3494570802059274, 2.590434103878804, 2.659393225253446, 2.378241913724034, 2.1723508632196484, 2.091214792249619, 1.946597598917015, 1.960408589643588, 2.2981147133448165, 1.9383338566125916, 1.7967990109462157, 1.9207057683957733, 1.8971873466561673, 1.8243558397306652, 4.0679560889607576, 17.57645491874915, 2.534023304781741, 4.34810940997683, 2.740153625285403, 3.595823954715651, 3.4123079288700295, 3.189448111125935, 2.4162323944763147, 2.804150028730957, 2.909298756405627, 4.285879558958477, 4.234835606542841, 3.807001151391777, 7.747694212153741, 2.956543574 ...
