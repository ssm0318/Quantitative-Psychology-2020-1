# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import os
import textract
from konlpy.tag import *
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import csv
# %matplotlib inline

# %%
from IPython.display import set_matplotlib_formats
matplotlib.rc('font',family = 'Malgun Gothic')
set_matplotlib_formats('retina')
matplotlib.rc('axes',unicode_minus = False)

# %%
twitter = Okt()

text = ""
morphs = []

df = pd.read_csv('adoor_data/answers.csv', encoding='UTF8')
df['created_at'] = pd.to_datetime(df['created_at'])
# df = df[(df.author_id != 5)]

# %%
start_date = pd.Timestamp(2019, 1, 28, 0)
end_date = pd.Timestamp(2019, 4, 1, 0)

mask = (df['created_at'] > start_date) & (df['created_at'] <= end_date)
df = df.loc[mask]

df.head()
# Out:
#    id  author_id  question_id  \
# 0   1          5          236
# 1   2          5          103
# 2   3          5           98
# 3   4          5           95
# 4   6          4            5
#
#                                              content  tag_string  \
# 0  오늘 상담쌤과 칭찬에 대한 대화를 나눴다. 내가 애들의 칭찬을 잘 못 믿는, 그리고...         NaN
# 1         원하는 순간에 생각의 흐름을 멈추고 하고자 하는 일에 집중할 수 있는 능력.         NaN
# 2                              가만히 공상/유튜브. 혼자 있는 시간.         NaN
# 3  게으름. 그 중에서도 요즘 가장 싫은건 게으름으로 인해 더러워진 방. 너무 짜증나서...         NaN
# 4                     진수니랑 같이 프론트 더 멋있게 만들기!!!!!\r\n         NaN
#
#                   created_at                  updated_at
# 0 2019-01-28 14:11:42.543635  2019-01-28 14:11:42.543635
# 1 2019-01-28 14:12:09.623446  2019-01-28 14:12:09.623446
# 2 2019-01-28 14:13:16.547800  2019-01-28 14:13:16.547800
# 3 2019-01-28 14:14:38.838070  2019-01-28 14:14:38.838070
# 4 2019-01-28 15:55:14.088330  2019-01-28 15:55:14.088330

# %%
content = df.content

for row in content:
    text = row
    if not pd.isna(text):
        morphs.append(twitter.pos(text))

# %%
print(morphs)
# Out:
# [[('오늘', 'Noun'), ('상담', 'Noun'), ('쌤', 'Noun'), ('과', 'Josa'), ('칭찬', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('대화', 'Noun'), ('를', 'Josa'), ('나눴다', 'Verb'), ('.', 'Punctuation'), ('내', 'Noun'), ('가', 'Josa'), ('애', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('칭찬', 'Noun'), ('을', 'Josa'), ('잘', 'Verb'), ('못', 'Noun'), ('믿는', 'Verb'), (',', 'Punctuation'), ('그리고', 'Conjunction'), ('믿어도', 'Verb'), ('크게', 'Noun'), ('영향', 'Noun'), ('을', 'Josa'), ('받지', 'Verb'), ('않는', 'Verb'), ('이유', 'Noun'), ('를', 'Josa'), ('말씀드렸는데', 'Verb'), ('이해', 'Noun'), ('가', 'Josa'), ('된다고', 'Verb'), ('하셨다', 'Verb'), ('.', 'Punctuation')], [('원하는', 'Adjective'), ('순간', 'Noun'), ('에', 'Josa'), ('생각', 'Noun'), ('의', 'Josa'), ('흐름', 'Noun'), ('을', 'Josa'), ('멈추고', 'Verb'), ('하고자', 'Verb'), ('하는', 'Verb'), ('일', 'Noun'), ('에', 'Josa'), ('집중', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('능력', 'Noun'), ('.', 'Punctuation')], [('가만히', 'Adverb'), ('공상', 'Noun'), ('/', 'Punctuation'), ('유튜브', 'Noun'), ('.', 'Punctuation'), ('혼자', 'Noun'), ('있는', 'Adjective'), ('시간', 'Noun'), ('.', 'Punctuation')], [('게으름', 'Noun'), ('.', 'Punctuation'), ('그', 'Noun'), ('중', 'Noun'), ('에서도', 'Josa'), ('요즘', 'Noun'), ('가장', 'Noun'), ('싫은건', 'Adjective'), ('게으름', 'Noun'), ('으로', 'Josa'), ('인해', 'Adjective'), ('더러워진', 'Verb'), ('방', 'Noun'), ('.', 'Punctuation'), ('너무', 'Adverb'), ('짜증나서', 'Adjective'), ('오늘', 'Noun'), ('아침', 'Noun'), ('늦었는데', 'Verb'), ('세면대', 'Noun'), ('닦았다', 'Verb'), ('.', 'Punctuation'), ('곧', 'Noun'), ('자취', 'Noun'), ('방', 'Noun'), ('뒤집어', 'Verb'), ('놔야지', 'Verb'), ('.', 'Punctuation')], [('진', 'Noun'), ('수니', 'Noun'), ('랑', 'Josa'), ('같이', 'Adverb'), ('프론트', 'Noun'), ('더', 'Noun'), ('멋있게', 'Adjective'), ('만들기', 'Noun'), ('!!!!!', 'Punctuation'), ('\r\n', 'Foreign')], [('나', 'Noun'), ('는', 'Josa'), ('칭찬', 'Noun'), ('받는걸', 'Verb'), ('좋아하고', 'Adjective'), ('칭찬', 'Noun'), ('하는것도', 'Verb'), ('좋아한다', 'Adjective'), ('!', 'Punctuation'), ('칭찬', 'Noun'), ('은', 'Josa'), ('내', 'Noun'), ('가', 'Josa'), ('일', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('가장', 'Noun'), ('큰', 'Verb'), ('원동력', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation'), ('작은', 'Adjective'), ('칭찬', 'Noun'), ('도', 'Josa'), ('하루', 'Noun'), ('종일', 'Noun'), ('기분', 'Noun'), ('날아갈', 'Verb'), ('것', 'Noun'), ('같이', 'Adverb'), ('만', 'Noun'), ('들어준다', 'Verb'), ('.', 'Punctuation'), ('(', 'Punctuation'), ('과장', 'Noun'), ('이', 'Josa'), ('아니다', 'Adjective'), ('.)', 'Punctuation'), ('\r\n\r\n', 'Foreign'), ('그리고', 'Conjunction'), ('친구', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('내', 'Noun'), ('가', 'Josa'), ('칭찬', 'Noun'), ('에', 'Josa'), ('후', 'Noun'), ('하다고', 'Verb'), ('하지만', 'Conjunction'), ('나', 'Noun'), ('는', 'Josa'), ('진짜진짜', 'Noun'), ('억울한', 'Adjective'), ('것', 'Noun'), ('이', 'Josa'), ('있다', 'Adjective'), ('!!!!!', 'Punctuation'), ('나', 'Noun'), ('는', 'Josa'), ('정말', 'Noun'), ('내', 'Noun'), ('가', 'Josa'), ('칭찬', 'Noun'), ('할만', 'Verb'), ('하다고', 'Verb'), ('생각', 'Noun'), ('해서', 'Verb'), ('칭찬', 'Noun'), ('한다', 'Verb'), ('!!!!', 'Punctuation'), ('절대', 'Noun'), ('빈말', 'Noun'), ('이', 'Josa'), ('아니다', 'Adjective'), ('...', 'Punctuation'), ('그렇', 'Adjective'), ('기도', 'Noun'), ('하고', 'Verb'), ('칭찬', 'Noun'), ('을', 'Josa'), ('하면', 'Verb'), ('뭔가', 'Noun'), ('상대방', 'Noun'), ('에게', 'Josa'), ('소소한', 'Adjective'), ('행복', 'Noun'), ('을', 'Josa'), ('선물', 'Noun'), ('해주는', 'Verb'), ('거', 'Noun'), ('같아서', 'Adjective'), ('(', 'Punctuation'), ('아닐', 'Adjective'), ('수도', 'Noun'), ('있지만', 'Adjective'), (')', 'Punctuation'), ('기분', 'Noun'), ('이', 'Josa'), ('좋', 'Adjective'), ('기도', 'Noun'), ('하다', 'Verb'), ('.', 'Punctuation')], [('자신감', 'Noun'), ('없는거', 'Adjective')], [('로또', 'Noun'), ('당첨', 'Noun'), ('재능', 'Noun'), ('(', 'Punctuation'), ('이', 'Determiner'), ('것', 'Noun'), ('도', 'Josa'), ('재능', 'Noun'), ('인가', 'Josa'), ('여', 'Noun'), ('?)', 'Punctuation')], [('나', 'Noun'), ('는', 'Josa'), ('선택', 'Noun'), ('에', 'Josa'), ('있어서', 'Adjective'), ('무섭도록', 'Adjective'), ('직감', 'Noun'), ('을', 'Josa'), ('믿는다', 'Verb'), ('\r\ ...

# %%
noun_adj_adv_list=[]
 
for sentence in morphs :
    for word, tag in sentence :
        if tag in ['Noun'] and len(word) > 1:
            noun_adj_adv_list.append(word)
# Out:
#   File "<ipython-input-7-2c1f7ea553e0>", line 5
#     if tag in ['Noun'] and len(word) > 1 and word not in ['것', '내', '나', '말', '수', '그', '게', '거']
#                                                                                                  ^
# SyntaxError: invalid syntax

# %%
print(noun_adj_adv_list)

# %%
count = Counter(noun_adj_adv_list)
words = dict(count.most_common())
words

# %%
wordcloud = WordCloud(font_path = '~/Library/Fonts/malgun.ttf', background_color='white',colormap = "Accent_r",
                      width=1500, height=1000).generate_from_frequencies(words)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()
