# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import os
import textract
from konlpy.tag import *
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import csv
# %matplotlib inline

# %%
from IPython.display import set_matplotlib_formats
matplotlib.rc('font',family = 'Malgun Gothic')
set_matplotlib_formats('retina')
matplotlib.rc('axes',unicode_minus = False)

# %%
twitter = Okt()

text = ""
morphs = []

df = pd.read_csv('sns_feed.csv', encoding='UTF8')

# df = df[(df.adoor != 5)]

df.head()
# Out:
#   adoor        SNS   SNS 아이디 private  created_at        photo  \
# 0     2   facebook       김유리   False  2019/02/08           홍보
# 1     2  instagram  nnnyu_ri   False  2019/02/08           홍보
# 2     2  instagram  yulo_mon    True  2019/02/07  가족, 아기, 강아지
# 3     2  instagram  yulo_mon    True  2019/02/25           일상
# 4     2  instagram  yulo_mon    True  2019/03/02          나들이
#
#                                              content
# 0  저와 팀원들이 영혼을 갈아넣은 서비스 베타버전이 드디어 나왔어요!!🤩\n밤잠을 줄여...
# 1  https://adoor.app @adoor.team\n저와 팀원들이 영혼을 갈아넣...
# 2                               카조꾸또 잇쇼니 토떼모 우레시깟딴데쓰
# 3                                              🙋🏻‍♀️
# 4  필름캐머러 첫 롤 사진들1\n수라미가 준 로모그래피 심플유즈 기본 장착 컬러네거티브...

# %%
content = df.content
tags = df.photo

for row in content:
    text = row
    if not pd.isna(text):
        morphs.append(twitter.pos(text))
        
for row in tags:
    text = row
    if not pd.isna(text):
        morphs.append(twitter.pos(text))

# %%
print(morphs)
# Out:
# [[('저', 'Noun'), ('와', 'Josa'), ('팀', 'Noun'), ('원', 'Suffix'), ('들이', 'Verb'), ('영혼', 'Noun'), ('을', 'Josa'), ('갈아', 'Adverb'), ('넣은', 'Verb'), ('서비스', 'Noun'), ('베타', 'Noun'), ('버전', 'Noun'), ('이', 'Josa'), ('드디어', 'Adverb'), ('나왔어요', 'Verb'), ('!!', 'Punctuation'), ('🤩', 'Foreign'), ('\n', 'Foreign'), ('밤잠', 'Noun'), ('을', 'Josa'), ('줄여가며', 'Verb'), ('코피', 'Noun'), ('를', 'Josa'), ('흘려가며', 'Verb'), ('스카이', 'Noun'), ('캐슬', 'Noun'), ('도', 'Josa'), ('안보', 'Noun'), ('면서', 'Noun'), ('만들었어요', 'Verb'), ('~', 'Punctuation'), ('\n', 'Foreign'), ('꼭', 'Noun'), ('써', 'Verb'), ('보시', 'Noun'), ('고', 'Josa'), ('친구', 'Noun'), ('들', 'Suffix'), ('에게도', 'Josa'), ('많이', 'Modifier'), ('많이', 'Modifier'), ('공유', 'Noun'), ('해주세요', 'Verb'), ('🥰', 'Foreign'), ('\n', 'Foreign'), ('🌷', 'Foreign'), ('고생', 'Noun'), ('한', 'Josa'), ('팀원', 'Noun'), ('들', 'Suffix'), ('앞', 'Noun'), ('으로도', 'Josa'), ('함께', 'Adverb'), ('해', 'Noun'), ('요', 'Josa'), (',,,', 'Punctuation'), ('이수정', 'Noun'), ('구', 'Modifier'), ('진선', 'Noun'), ('JaeWon', 'Alpha'), ('Kim', 'Alpha'), ('+', 'Punctuation'), ('약간', 'Noun'), ('의', 'Josa'), ('각', 'Modifier'), ('경이', 'Noun'), ('이', 'Determiner'), ('가경', 'Noun')], [('https://adoor.app', 'URL'), ('@adoor', 'ScreenName'), ('.', 'Punctuation'), ('team', 'Alpha'), ('\n', 'Foreign'), ('저', 'Noun'), ('와', 'Josa'), ('팀', 'Noun'), ('원', 'Suffix'), ('들이', 'Verb'), ('영혼', 'Noun'), ('을', 'Josa'), ('갈아', 'Adverb'), ('넣은', 'Verb'), ('서비스', 'Noun'), ('베타', 'Noun'), ('버전', 'Noun'), ('이', 'Josa'), ('드디어', 'Adverb'), ('나왔어요', 'Verb'), ('!!', 'Punctuation'), ('🤩', 'Foreign'), ('\n', 'Foreign'), ('밤잠', 'Noun'), ('을', 'Josa'), ('줄여가며', 'Verb'), ('코피', 'Noun'), ('를', 'Josa'), ('흘려가며', 'Verb'), ('스카이', 'Noun'), ('캐슬', 'Noun'), ('도', 'Josa'), ('안보', 'Noun'), ('면서', 'Noun'), ('만들었어요', 'Verb'), ('~', 'Punctuation'), ('\n', 'Foreign'), ('꼭', 'Noun'), ('써', 'Verb'), ('보시', 'Noun'), ('고', 'Josa'), ('친구', 'Noun'), ('들', 'Suffix'), ('에게도', 'Josa'), ('많이', 'Modifier'), ('많이', 'Modifier'), ('공유', 'Noun'), ('해주세요', 'Verb'), ('🥰', 'Foreign')], [('카', 'Noun'), ('조', 'Suffix'), ('꾸', 'Verb'), ('또', 'Noun'), ('잇', 'Verb'), ('쇼니', 'Noun'), ('토떼모', 'Noun'), ('우레', 'Noun'), ('시', 'Modifier'), ('깟', 'Modifier'), ('딴', 'Modifier'), ('데쓰', 'Noun')], [('🙋🏻\u200d♀️', 'Foreign')], [('필름', 'Noun'), ('캐머러', 'Noun'), ('첫', 'Noun'), ('롤', 'Noun'), ('사진', 'Noun'), ('들', 'Suffix'), ('1', 'Number'), ('\n', 'Foreign'), ('수', 'Modifier'), ('라미', 'Noun'), ('가', 'Josa'), ('준', 'Noun'), ('로모그래피', 'Noun'), ('심플', 'Noun'), ('유즈', 'Noun'), ('기본', 'Noun'), ('장착', 'Noun'), ('컬러', 'Noun'), ('네', 'Determiner'), ('거티브', 'Noun'), ('필름', 'Noun'), ('으루', 'Noun'), ('믓진', 'Noun'), ('나', 'Noun'), ('의', 'Josa'), ('친구', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('찍었다', 'Verb'), ('실패하는', 'Adjective'), ('경우', 'Noun'), ('도', 'Josa'), ('많다고', 'Adjective'), ('해서', 'Verb'), ('막', 'Noun'), ('찍어', 'Verb'), ('댔는데', 'Verb'), ('생각', 'Noun'), ('보다', 'Josa'), ('잘나왔다', 'Verb'), ('헤헤', 'Noun'), ('기대하는', 'Adjective'), ('행벅', 'Noun'), ('이', 'Josa'), ('있어서', 'Adjective'), ('앞', 'Noun'), ('으로도', 'Josa'), ('자주', 'Noun'), ('찍', 'Noun'), ('을', 'Josa'), ('거', 'Noun'), ('같다', 'Adjective'), ('!', 'Punctuation'), ('고마워', 'Adjective'), ('유', 'Noun'), ('수', 'Modifier'), ('라미', 'Noun'), ('!', 'Punctuation')], [('필름', 'Noun'), ('캐머러', 'Noun'), ('첫', 'Noun'), ('롤', 'Noun'), ('사진', 'Noun'), ('들', 'Suffix'), ('2', 'Number'), ('\n', 'Foreign'), ('카', 'Noun'), ('조', 'Suffix'), ('꾸와', 'Verb'), ('새로', 'Adjective'), ('이사', 'Noun'), ('한', 'Josa'), ('집', 'Noun'), ('을', 'Josa'), ('마구', 'Noun'), ('찍었', 'Verb'), ('슴', 'Noun'), ('네', 'Suffix'), ('다', 'Josa'), ('초상권', 'Noun'), ('은', 'Josa'), ('없슴네', 'Noun'), ('다', 'Josa')], [('우리', 'Noun'), ('동아리', 'Noun'), ('운영', 'Noun'), ('진', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('내일', 'Noun'), ('을', 'Josa'), ('위해', 'Noun'), ('운동장', 'Noun'), ('에', 'Josa'), ('멀', 'Adjective'), ('많이', 'Adverb'), ('설치', 'Noun'), ('하고', 'Josa'), ('버스', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('있었는데', 'Adjective'), ('거기', 'Noun'), ('에', ' ...

# %%
noun_adj_adv_list=[]
 
for sentence in morphs :
    for word, tag in sentence :
        if tag in ['Noun'] and len(word) > 1:
#         if tag in ['Noun'] and ("것" not in word) and ("내" not in word)and ("나" not in word)and ("그" not in word) and ("수"not in word) and("게"not in word)and("말"not in word)and("거" not in word) and ("생각" not in word) and ("사람" not in word):
            noun_adj_adv_list.append(word)

# %%
print(noun_adj_adv_list)
# Out:
# ['영혼', '서비스', '베타', '버전', '밤잠', '코피', '스카이', '캐슬', '안보', '면서', '보시', '친구', '공유', '고생', '팀원', '이수정', '진선', '약간', '경이', '가경', '영혼', '서비스', '베타', '버전', '밤잠', '코피', '스카이', '캐슬', '안보', '면서', '보시', '친구', '공유', '쇼니', '토떼모', '우레', '데쓰', '필름', '캐머러', '사진', '라미', '로모그래피', '심플', '유즈', '기본', '장착', '컬러', '거티브', '필름', '으루', '믓진', '친구', '경우', '헤헤', '행벅', '자주', '라미', '필름', '캐머러', '사진', '이사', '마구', '초상권', '없슴네', '우리', '동아리', '운영', '내일', '위해', '운동장', '설치', '버스', '거기', '플래카드', '여러', '보고', '진짜', '고생', '갑자기', '버스', '운동장', '부터', '갑자기', '애가', '우산', '잡고', '여기', '저기', '그것', '아주', '다른', '처음', '약간', '우산', '손잡이', '우산', '도시', '착지', '줄타기', '아주', '줄타기', '천재', '핬다', '길이', '건너편', '선수', '그냥', '여자', '여자', '여자', '여자', '머리', '허리', '상태', '날갯짓', '점점', '위로', '상공', '위로', '진짜', '전깃줄', '전깃줄', '잡고', '가다가', '저택', '마당', '수영장', '거길', '점프', '수영장', '차로', '점프', '수석', '유리', '착지', '운전사', '다시', '저택', '창문', '거기', '악당', '애도', '따라서', '우리', '악당', '낌새', '우리', '여기저기', '커튼', '순간', '다시', '전깃줄', '잡고', '슬라이딩', '슝슝', '악당', '줄타기', '장인', '보고', '다른', '타고', '전깃줄', '도시', '구경', '아주', '상공', '최고', '필름', '카메라', '두번째', '사용', '아주', '의미', '사진', '느낌', '멀리', '실내', '필름', '카메라', '다른', '찍기', '시작', '바지', '바지', '가장', '아주', '따숩기', '거기', '다가', '무척', '힙해', '하나', '불교', '용품', '팔고', '걸음', '수니', '약과', '스님', '평생', '바지', '택하', '아주', '일이', '절밥', '무척', '연잎밥', '연잎', '브로콜리', '간이', '곤약', '볶음', '쫄깃', '김치', '젓갈', '비건', '무척', '스님', '말씀', '어기', '경지', '이불', '운지', '시간', '고등', '래퍼', '하나', '보기', '첫인상', '보기', '언니', '코고', '소리', '수니', '기침', '소리', '정신', '명상', '시간', '무슨', '일이', '명상', '시간', '시간', '다음', '제일', '시간', '몹시', '실망', '일단', '스님', '부터', '상처', '그것', '하나', '마음속', '상처', '블랙홀', '심호흡', '요런', '연속', '시간', '듣기', '스님', '걸음', '몹시', '속도', '의문', '정도', '또한', '여유', '스케줄', '저리', '자칫', '무언가', '음미', '시간', '빡빡', '일정', '허슬', '라이프', '끝판', '타이', '허슬', '스님', '걸음', '이유', '스님', '일상', '여기', '모든', '직장', '생활', '번뇌', '이야기', '마음', '스님', '일생', '마음', '이해', '이야기', '그녀', '일화', '조금', '표현', '마음', '그녀', '누구', '누구', '그녀', '대한', '신뢰', '내일', '그녀', '하니', '스님', '대한', '믿음', '템플스테이', '의식', '감각', '경험', '소리', '내일', '아침', '공양', '무척', '기대', '벌써', '약간', '몹시', '상주', '해소', '이상', '만들기', '위해', '매일', '진선', '이수정', '친구', '일단', '가입', '친구', '사용', '후회', '크롬', '최적화', '도움', '주신', '멋쟁이', '사자', '서울대학교', '핸드폰', '이전', '계정', '비번', '연결', '이메일', '해킹', '가지', '계정', '이전', '계정', '연락', '미래', '감히', '일단', '오늘', '역시', '팀원', '미래', '인재', '학교', '후기', '재미', '감흥', '이원석', '언제', '어디', '서나', '포즈', '사진', '대부분', '고기', '절밥', '느낌', '자주', '평창', '사진', '첫인상', '벌써', '이쯤', '얼굴', '샤대', '정석', '미안', '진짜', '해외', '크게', '막상', '해외', '생활', '해외', '고생', '그냥', '준희', '교수', '중세', '대학', '강의', '프로그램', '가장', '의미', '부분', '최근', '자극', '인사이트', '인내심', '대화', '머리', '평균', '이하', '공대생', '교양', '인문학', '도의', '기술', '모두', '무식', '이틀', '꼬박', '머리', '상태', '상태', '졸업식', '마카롱', '받곸', '방학', '동안', '어도', '이상', '걱정', '예상', '장수', '보스', '타고', '정신', '차려', '신림역', '이번', '졸업식', '최애', '사진', '네이버', '인재', '사진', '표정', '기분', '아보', '지금', '수면', '패턴', '때문', '지금', '유튜브', '채널', '이름', '감귤', '개구리', '퓨저', '조우', '처음', '상품', '레몬', '스티', '개봉', '퓨저', '사용', '방법', '소식', '교회', '잠식', '아주', '무슨', '동남아', '모기', '퇴치', '정감', '녹차', '주전자', '뚜껑', '린다', '디테', '일이', '정말', '선물', '진짜', '지금', '코노', '발견', '주변', '부스', '노래', '단점', '어메이징', '차지', '바로', '지에스', '이디야', '분명', '그저께', '해도', '존재', '갑자기', '간판', '모든', '촥촥촥', '이틀', '거의', '완공', '녹두', '라이프', '더욱', '이유', '상태', '여드름', '오만', '오늘', '녹음', '계속', '시도', '기운', '번만', '모야', '거왜', '득템', '산수', '머리', '하이파이브', '낌새', '보이', '절대', '별로', '강아지', '방법', '누가', '그냥', '쓰레기통', '우리나라', '쓰레기통', '아주', '자유', '어도', '회의', '기록', '학교', '학교', '비합리적', '요구', '순응', '그것', '조성하', '불안감', '동요', '순간', '그것', '낭비', '시간', '학교', '세상', '모든', '시스템', '제일', '시스템', '시스템', '매일', '시스템', '시스템', '정체', '비합리적', '투성이', '애초', '점수', '만큼', '존재', '목적', '살다보면', '장애물', '무엇', '무엇', '사회', '회피', '이해', '시스템', '억지로', '부품', '마음', '이상', '공개', '돈키호테', '재리', '밍키', '루니', '아렁', '호두', '자네', '코코', '매뇽리', '코코', '메리', '최고다', '오늘', '예지', '예지', '변신', '예지', '우쿨렐레', '강남역', '스트랩', '고민', '홍콩과기대', '교수', '큐티함', '열정', '이미지', '방법', '설명', '케이스', '빨강', '파랑', '색칠', '직접', '비록', '과제', '기한', '착각', '오늘', '새벽', '강제', '드랍', '매우', '기억', '전액', '장학금 ...

# %%
count = Counter(noun_adj_adv_list)
words = dict(count.most_common())
words
# Out:
# {'친구': 26,
#  '일상': 17,
#  '강아지': 15,
#  '사진': 12,
#  '음식': 12,
#  '셀카': 11,
#  '홍보': 10,
#  '캡쳐': 10,
#  '그것': 9,
#  '아주': 9,
#  '마음': 9,
#  '오늘': 9,
#  '우리': 8,
#  '진짜': 8,
#  '스님': 8,
#  '시간': 8,
#  '노래': 8,
#  '사용': 7,
#  '학교': 7,
#  '여행': 7,
#  '방탄소년단': 7,
#  '머리': 6,
#  '일단': 6,
#  '시스템': 6,
#  '필름': 5,
#  '일이': 5,
#  '소리': 5,
#  '모든': 5,
#  '방학': 5,
#  '생일': 5,
#  '베타': 4,
#  '버전': 4,
#  '내일': 4,
#  '위해': 4,
#  '그냥': 4,
#  '여자': 4,
#  '상태': 4,
#  '전깃줄': 4,
#  '무척': 4,
#  '제일': 4,
#  '그녀': 4,
#  '누구': 4,
#  '대한': 4,
#  '매일': 4,
#  '가입': 4,
#  '후회': 4,
#  '모두': 4,
#  '동안': 4,
#  '어도': 4,
#  '방법': 4,
#  '계속': 4,
#  '공개': 4,
#  '거리': 4,
#  '당신': 4,
#  '양강': 4,
#  '레드': 4,
#  '벨벳': 4,
#  '가족': 4,
#  '본인': 4,
#  '드로잉': 4,
#  '트위터': 4,
#  '서비스': 3,
#  '고생': 3,
#  '팀원': 3,
#  '이수정': 3,
#  '약간': 3,
#  '자주': 3,
#  '거기': 3,
#  '갑자기': 3,
#  '우산': 3,
#  '잡고': 3,
#  '다른': 3,
#  '줄타기': 3,
#  '위로': 3,
#  '다시': 3,
#  '악당': 3,
#  '의미': 3,
#  '바지': 3,
#  '가장': 3,
#  '하나': 3,
#  '걸음': 3,
#  '몹시': 3,
#  '라이프': 3,
#  '이유': 3,
#  '아침': 3,
#  '벌써': 3,
#  '이상': 3,
#  '계정': 3,
#  '해외': 3,
#  '프로그램': 3,
#  '이번': 3,
#  '기분': 3,
#  '지금': 3,
#  '정말': 3,
#  '기록': 3,
#  '세상': 3,
#  '무엇': 3,
#  '예지': 3,
#  '날씨': 3,
#  '부산': 3,
#  '통제': 3,
#  '지민': 3,
#  '게임': 3,
#  '스포츠': 3,
#  '영혼': 2,
#  '밤잠': 2,
#  '코피': 2,
#  '스카이': 2,
#  '캐슬': 2,
#  '안보': 2,
#  '면서': 2,
#  '보시': 2,
#  '공유': 2,
#  '진선': 2,
#  '캐머러': 2,
#  '라미': 2,
#  '헤헤': 2,
#  '마구': 2,
#  '운동장': 2,
#  '버스': 2,
#  '보고': 2,
#  '부터': 2,
#  '여기': 2,
#  '처음': 2,
#  '도시': 2,
#  '착지': 2,
#  '허리': 2,
#  '상공': 2,
#  '저택': 2,
#  '수영장': 2,
#  '점프': 2,
#  '낌새': 2,
#  '순간': 2,
#  '타고': 2,
#  '최고': 2,
#  '카메라': 2,
#  '느낌': 2,
#  '시작': 2,
#  '수니': 2,
#  '절밥': 2,
#  '볶음': 2,
#  '보기': 2,
#  '첫인상': 2,
#  '정신': 2,
#  '명상': 2,
#  '무슨': 2,
#  '상처': 2,
#  '연속': 2,
#  '정도': 2,
#  '또한': 2,
#  '저리': 2,
#  '허슬': 2,
#  '생활': 2,
#  '이야기': 2,
#  '이해': 2,
#  '기대': 2,
#  '크롬': 2,
#  '최적화': 2,
#  '이전': 2,
#  '미래': 2,
#  '인재': 2,
#  '재미': 2,
#  '얼굴': 2,
#  '크게': 2,
#  '막상': 2,
#  '교수': 2,
#  '대화': 2,
#  '이틀': 2,
#  '졸업식': 2,
#  '네이버': 2,
#  '때문': 2,
#  '유튜브': 2,
#  '퓨저': 2,
#  '해도': 2,
#  '존재': 2,
#  '거의': 2,
#  '보이': 2,
#  '쓰레기통': 2,
#  '비합리적': 2,
#  '코코': 2,
#  '이미지': 2,
#  '직접': 2,
#  '비록': 2,
#  '새벽': 2,
#  '기억': 2,
#  '데스크탑': 2,
#  '권장': 2,
#  '페이스북': 2,
#  '피땀': 2,
#  '눈물': 2,
#  '고고': 2,
#  '여러분': 2,
#  '기념': 2,
#  '드라이브': 2,
#  '추천': 2,
#  '저녁': 2,
#  '약속': 2,
#  '무릅쓰': 2,
#  '요즘': 2,
#  '이제': 2,
#  '러닝': 2,
#  '개강': 2,
#  '육체': 2,
#  '추억': 2,
#  '음악': 2,
#  '시대': 2,
#  '증자': 2,
#  '모듈': 2,
#  '포착': 2,
#  '공포': 2,
#  '촉각': 2,
#  '사실': 2,
#  '돼지': 2,
#  '살점': 2,
#  '매혹': 2,
#  '화면': 2,
#  '시점': 2,
#  '젤리': 2,
#  '혼자': 2,
#  '경기': 2,
#  '자랑': 2,
#  '민윤기': 2,
#  '습관': 2,
#  '병원': 2,
#  '기절': 2,
#  '카페': 2,
#  '카톡': 2,
#  '간식': 2,
#  '바다': 2,
#  '연예인': 2,
#  '경이': 1,
#  '가경': 1,
#  '쇼니': 1,
#  '토떼모': 1,
#  '우레': 1,
#  '데쓰': 1,
#  '로모그래피': 1,
#  '심플': 1,
#  '유즈': 1,
#  '기본': 1,
#  '장착': 1,
#  '컬러': 1,
#  '거티브': 1,
#  '으루': 1,
#  '믓진': 1,
#  '경우': 1,
#  '행벅': 1,
#  '이사': 1,
#  '초상권': 1,
#  '없슴네': 1,
#  '동아리': 1,
#  '운영': 1,
#  '설치': 1,
#  '플래카드': 1,
#  '여러': 1,
#  '애가': 1,
#  '저기': 1,
#  '손잡이': 1,
#  '천재': 1,
#  '핬다': 1,
#  '길이': 1,
#  '건너편': 1,
#  '선수': 1,
#  '날갯짓': 1,
#  '점점': 1,
#  '가다가': 1,
#  '마당': 1,
#  '거길': 1,
#  '차로': 1,
#  '수석': 1,
#  '유리': 1,
#  '운전사': 1,
#  '창문': 1,
#  '애도': 1,
#  '따라서': 1,
#  '여기저기': 1,
#  '커튼': 1,
#  '슬라이딩': 1,
#  '슝슝': 1,
#  '장인': 1,
#  '구경': 1,
#  '두번째': 1,
#  '멀리': 1,
#  '실내': 1,
#  '찍기': 1,
#  '따숩기': 1,
#  '다가': 1,
#  '힙해': 1,
#  '불교': 1,
#  '용품': 1,
#  '팔고': 1,
#  '약과': 1,
#  '평생': 1,
#  '택하': 1,
#  '연잎밥': 1,
#  '연잎': 1,
#  '브로콜리': 1,
#  '간이': 1,
#  '곤약': 1,
#  '쫄깃': 1,
#  '김치': 1,
#  '젓갈': 1,
#  '비건': 1,
#  '말씀': 1,
#  '어기': 1,
#  '경지': 1,
#  '이불': 1,
#  '운지': 1,
#  '고등': 1,
#  '래퍼': 1,
#  '언니': 1,
#  '코고': 1,
#  '기침': 1,
#  '다음': 1,
#  '실망': 1,
#  '마음속': 1,
#  '블랙홀': 1,
#  '심호흡': 1,
#  '요런': 1,
#  '듣기': 1,
#  '속도': 1,
#  '의문': 1,
#  '여유': 1,
#  '스케줄': 1,
#  '자칫': 1,
#  '무언가': 1,
#  '음미': 1,
#  '빡빡': 1,
#  '일정': 1,
#  '끝판': 1,
#  '타이': 1,
#  '직장': 1,
#  '번뇌': 1,
#  '일생': 1,
#  '일화': 1,
#  '조금': 1,
#  '표현': 1,
#  '신뢰': 1,
#  '하니': 1,
#  '믿음': 1,
#  '템플스테이': 1,
#  '의식': 1,
#  '감각': 1,
#  '경험': 1,
#  '공양': 1,
#  '상주': 1,
#  '해소': 1,
#  '만들기': 1,
#  '도움': 1,
#  '주신': 1,
#  '멋쟁이': 1,
#  '사자': 1,
#  '서울대학교': 1,
#  '핸드폰': 1,
#  '비번': 1,
#  '연결': 1,
#  '이메일': 1,
#  '해킹': 1,
#  '가지': 1,
#  '연락': 1,
#  '감히': 1,
#  '역시': 1,
#  '후기': 1,
#  '감흥': 1,
#  '이원석': 1,
#  '언제': 1,
#  '어디': 1,
#  '서나': 1,
#  '포즈': 1,
#  '대부분': 1,
#  '고기': 1,
#  '평창': 1,
#  '이쯤': 1,
#  '샤대': 1,
#  '정석': 1,
#  '미안': 1,
#  '준희': 1,
#  '중세': 1,
#  '대학': 1,
#  '강의': 1,
#  '부분': 1,
#  '최근': 1,
#  '자극': 1,
#  '인사이트': 1,
#  '인내심': 1,
#  '평균': 1,
#  '이하': 1,
#  '공대생': 1,
#  '교양': 1,
#  '인문학': 1,
#  '도의': 1,
#  '기술': 1,
#  '무식': 1,
#  '꼬박': 1,
#  '마카롱': 1,
#  '받곸': 1,
#  '걱정': 1,
#  '예상': 1,
#  '장수': 1,
#  '보스': 1,
#  '차려': 1,
#  '신림역': 1,
#  '최애': 1,
#  '표정': 1,
#  '아보': 1,
#  '수면': 1,
#  '패턴': 1,
#  '채널': 1,
#  '이름': 1,
#  '감귤': 1,
#  '개구리': 1,
#  '조우': 1,
#  '상품': 1,
#  '레몬': 1,
#  '스티': 1,
#  '개봉': 1,
#  '소식': 1,
#  '교회': 1,
#  '잠식': 1,
#  '동남아': 1,
#  '모기': 1,
#  '퇴치': 1,
#  '정감': 1,
#  '녹차': 1,
#  '주전자': 1,
#  '뚜껑': 1,
#  '린다': 1,
#  '디테': 1,
#  '선물': 1,
#  '코노': 1,
#  '발견': 1,
#  '주변': 1,
#  '부스': 1,
#  '단점': 1,
#  '어메이징': 1,
#  '차지': 1,
#  '바로': 1,
#  '지에스': 1,
#  '이디야': 1,
#  '분명': 1,
#  '그저께': 1,
#  '간판': 1,
#  '촥촥촥': 1,
#  '완공': 1,
#  '녹두': 1,
#  '더욱': 1,
#  '여드름': 1,
#  '오만': 1,
#  '녹음': 1,
#  '시도': 1,
#  '기운': 1,
#  '번만': 1,
#  '모야': 1,
#  '거왜': 1,
#  '득템': 1,
#  '산수': 1,
#  '하이파이브': 1,
#  '절대': 1,
#  '별로': 1,
#  '누가': 1,
#  '우리나라': 1,
#  '자유': 1,
#  '회의': 1,
#  '요구': 1,
#  '순응': 1,
#  '조성하': 1,
#  '불안감': 1,
#  '동요': 1,
#  '낭비': 1,
#  '정체': 1,
#  '투성이': 1,
#  '애초': 1,
#  '점수': 1,
#  '만큼': 1,
#  '목적': 1,
#  '살다보면': 1,
#  '장애물': 1,
#  '사회': 1,
#  '회피': 1,
#  '억지로': 1,
#  '부품': 1,
#  '돈키호테': 1,
#  '재리': 1,
#  '밍키': 1,
#  '루니': 1,
#  '아렁': 1,
#  '호두': 1,
#  '자네': 1,
#  '매뇽리': 1,
#  '메리': 1,
#  '최고다': 1,
#  '변신': 1,
#  '우쿨렐레': 1,
#  '강남역': 1,
#  '스트랩': 1,
#  '고민': 1,
#  '홍콩과기대': 1,
#  '큐티함': 1,
#  '열정': 1,
#  '설명': 1,
#  '케이스': 1,
#  '빨강': 1,
#  '파랑': 1,
#  '색칠': 1,
#  '과제': 1,
#  '기한': 1,
#  '착각': 1,
#  '강제': 1,
#  '드랍': 1,
#  '매우': 1,
#  '전액': 1,
#  '장학금': 1,
#  '대도': 1,
#  '학생': 1,
#  '비교': 1,
#  '양질': 1,
#  '수업': 1,
#  '빌리씌': 1,
#  '무한': 1,
#  '반복': 1,
#  '모바일': 1,
#  '김재원': 1,
#  '신세계': 1,
#  '체험': 1,
#  '퀄리티': 1,
#  '보장': 1,
#  '환영': 1,
#  '정우': 1,
#  '용유도': 1,
#  '송도': 1,
#  '구름': 1,
#  '피기': 1,
#  '할아범': 1,
#  '혀좀': 1,
#  '주무': 1,
#  '바삭': 1,
#  '다섯': 1,
#  '여수': 1,
#  '출근': 1,
#  '앞머리': 1,
#  '고마': 1,
#  '오근': 1,
#  '독일': 1,
#  '성의': 1,
#  '잔디밭': 1,
#  '햇빛': 1,
#  '누리': 1,
#  '샌드위치': 1,
#  '피크닉': 1,
#  '현실': 1,
#  '아스': 1,
#  '엉덩이': 1,
#  '페북': 1,
#  '메일': 1,
#  '회원': 1,
#  '허언증': 1,
#  '갤러리': 1,
#  '소름': 1,
#  '정자': 1,
#  '얼마나': 1,
#  '무릅쓸': 1,
#  '하나로': 1,
#  '학사모': 1,
#  '빈자리': 1,
#  '헛헛하': 1,
#  '관악': 1,
#  '지금껏': 1,
#  '따위': 1,
#  '순이': 1,
#  '놀이': 1,
#  '체고': 1,
#  '요약': 1,
#  '뿌듯': 1,
#  '밤샘': 1,
#  '메이트': 1,
#  '크루': 1,
#  '그린': 1,
#  '그래픽': 1,
#  '모나미': 1,
#  '콜라보': 1,
#  '실물': 1,
#  '영접': 1,
#  '디사': 1,
#  '수강생': 1,
#  '지난': 1,
#  '달이': 1,
#  '자의': 1,
#  '이다지': 1,
#  '입학': 1,
#  '복학': 1,
#  '킬링': 1,
#  '포인트': 1,
#  '바람': 1,
#  '시절': 1,
#  '머플러': 1,
#  '매기': 1,
#  '작가': 1,
#  '아날로그': 1,
#  '마흔': 1,
#  '앨범': 1,
#  '아우': 1,
#  '햇살': 1,
#  '아이스': 1,
#  '라떼': 1,
#  '오버': 1,
#  '나이트': 1,
#  '오트밀': 1,
#  '우왕': 1,
#  '부금': 1,
#  '경로': 1,
#  '추적': 1,
#  '아시': 1,
#  '아무': 1,
#  '인사': 1,
#  '아무나': 1,
#  '창궐': 1,
#  '역병': 1,
#  '병균': 1,
#  '바이러스': 1,
#  '원인': 1,
#  '포자': 1,
#  '성립': 1,
#  '뇌수': 1,
#  '장기': 1,
#  '유기물': 1,
#  '파편': 1,
#  '침대': 1,
#  '대로': 1,
#  '피부': 1,
#  '어제': 1,
#  '액체': 1,
#  '건너': 1,
#  '누군가': 1,
#  '도달': 1,
#  '부채': 1,
#  '역사': 1,
#  '전복': 1,
#  '극도': 1,
#  '상자': 1,
#  '소비': 1,
#  '복속': 1,
#  '신경증': 1,
#  '가슴': 1,
#  '선율': 1,
#  '폭력': 1,
#  '감정': 1,
#  '차이': 1,
#  '갈망': 1,
#  '진실': 1,
#  '욕망': 1,
#  '변화': 1,
#  '위함': 1,
#  '세기': 1,
#  '제작': 1,
#  '내장': 1,
#  '한번': 1,
#  '디자인': 1,
#  '구성은': 1,
#  '기능': 1,
#  '핑크색': 1,
#  '척추': 1,
#  '적임': 1,
#  '랜덤': 1,
#  '아파트': 1,
#  '미술': 1,
#  '전시': 1,
#  '디저트': 1,
#  '환상': 1,
#  '적재': 1,
#  '도처': 1,
#  '간다': 1,
#  '구조': 1,
#  '자체': 1,
#  '자연법칙': 1,
#  '동시': 1,
#  '각자': 1,
#  '촉감': 1,
#  '구심': 1,
#  '인류': 1,
#  '분할': 1,
#  '저장': 1,
#  '종류': 1,
#  '덩어리': 1,
#  '유령': 1,
#  '비명': 1,
#  '지층': 1,
#  '딸기': 1,
#  '감자': 1,
#  '양배추': 1,
#  '기필코': 1,
#  '주말': 1,
#  '분당': 1,
#  '만년': 1,
#  '호연': 1,
#  '세계': 1,
#  '여성': 1,
#  '나이키': 1,
#  '역대': 1,
#  '페스티벌': 1,
#  '상상': 1,
#  '홈페이지': 1,
#  '입장권': 1,
#  '필수': 1,
#  '신청': 1,
#  '참여': 1,
#  '게시': 1,
#  '영광': 1,
#  '겨울': 1,
#  '봄날': 1,
#  '어플': 1,
#  '미니': 1,
#  '침니': 1,
#  '이이이이이': 1,
#  '사랑': 1,
#  '박수영': 1,
#  '절제': 1,
#  '카타르': 1,
#  '시스': 1,
#  '쌜리': 1,
#  '시즌': 1,
#  '리야': 1,
#  '명령': 1,
#  '전설': 1,
#  '트럼본': 1,
#  '버거': 1,
#  '사이즈': 1,
#  '시리얼': 1,
#  '취향': 1,
#  '우유': 1,
#  '숟가락': 1,
#  '페이보릿': 1,
#  '양키': 1,
#  '교촌': 1,
#  '마리': 1,
#  '먹음': 1,
#  '스케치': 1,
#  '검도': 1,
#  '회식': 1,
#  '대전': 1,
#  '일어나서': 1,
#  '서서': 1,
#  '보람': 1,
#  '개꿀잼': 1,
#  '명의': 1,
#  '박수': 1,
#  '개잼': 1,
#  '블쟈': 1,
#  '뷰잉': 1,
#  '파티': 1,
#  '리그': 1,
#  '존잘': 1,
#  '미세먼지': 1,
#  '농도': 1,
#  '개뿔': 1,
#  '시발': 1,
#  '기관지': 1,
#  '좆창': 1,
#  '비주': 1,
#  '됴잉': 1,
#  '박짐': 1,
#  '무형문화재': 1,
#  '수상': 1,
#  '찜닭': 1,
#  '나야': 1,
#  '학기': 1,
#  '뻘글': 1,
#  '작년': 1,
#  '일과': 1,
#  '주축': 1,
#  '문득': 1,
#  '그때': 1,
#  '상해': 1,
#  '노력': 1,
#  '당시': 1,
#  '나날이': 1,
#  '제패': 1,
#  '조울증': 1,
#  '행동': 1,
#  '감시': 1,
#  '하루': 1,
#  '종일': 1,
#  '자게': 1,
#  '링거': 1,
#  '가게': 1,
#  '마찬가지': 1,
#  '감기': 1,
#  '약도': 1,
#  '생리': 1,
#  '먼저': 1,
#  '터득': 1,
#  '아이러니': 1,
#  '안정': 1,
#  '인위': 1,
#  '인공': 1,
#  '체계': 1,
#  '만족감': 1,
#  '리도': 1,
#  '실제': 1,
#  '기간': 1,
#  '인간관계': 1,
#  '성적': 1,
#  '문제': 1,
#  '갈라': 1,
#  '극복': 1,
#  '치부': 1,
#  '내겐': 1,
#  '이기': 1,
#  '올린다': 1,
#  '올해': 1,
#  '일만': 1,
#  '개월': 1,
#  '부추': 1,
#  '아마': 1,
#  '엄마': 1,
#  '이모티콘': 1,
#  '왼쪽': 1,
#  '골반': 1,
#  '난리': 1,
#  '주사': 1,
#  '생축': 1,
#  '월요병': 1,
#  '팬심': 1,
#  '수록': 1,
#  '아기': 1,
#  '나들이': 1,
#  '노래방': 1,
#  '낙서': 1,
#  '불빛': 1,
#  '악기': 1,
#  '연애': 1,
#  '일러스트': 1,
#  '쿠키': 1,
#  '노트북': 1,
#  '사무실': 1,
#  '과거': 1,
#  '건물': 1,
#  '기사': 1,
#  '과일': 1,
#  '취미': 1,
#  '풍경': 1,
#  '만화': 1,
#  '빙고': 1,
#  '쇼핑': 1,
#  '전자기기': 1,
#  '스피커': 1,
#  '공연': 1,
#  '게이머': 1,
#  '운동': 1,
#  '인형': 1,
#  '시간표': 1,
#  '고양이': 1,
#  '영상': 1,
#  '보드게임': 1,
#  '인스타그램': 1}

# %%
wordcloud = WordCloud(font_path = '../../Fonts/malgun.ttf', background_color='white',colormap = "Accent_r",
                      width=1500, height=1000).generate_from_frequencies(words)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()
